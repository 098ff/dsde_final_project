# %%
import os
from dotenv import load_dotenv
from typhoon_ocr import ocr_document
from IPython.display import display, Markdown

load_dotenv() 

api_key = os.getenv("TYPHOON_API_KEY")

# ตัวอย่างการใช้กับ PDF
markdown = ocr_document(
    pdf_or_image_path="../อำเภอบ้านไร่/ตำบลแก่นมะกรูด/หน่วยเลือกตั้งที่ 1/ส.ส.5ทับ18 (บช.).pdf",
    # pdf_or_image_path="../อำเภอบ้านไร่/ตำบลแก่นมะกรูด/หน่วยเลือกตั้งที่ 1/ส.ส.5ทับ18.pdf",
    page_num=1                         # ประมวลผลหน้าที่ 2 ของ PDF (ค่าเริ่มต้นคือ 1, สำหรับรูปภาพจะเป็น 1 เสมอ)
)

# %%
display(Markdown(markdown))
# Out:
# ส.ส. ๕/๑๘ (บช)
# สีขาว
#
# รายงานผลการนับคะแนนสมาชิกสภาผู้แทนราษฎรแบบบัญชีรายชื่อ
#
# (ให้กรอกทั้งตัวเลขและตัวอักษร)
#
# ตามที่ได้มีพระราชกฤษฎีกาให้มีการเลือกตั้งสมาชิกสภาผู้แทนราษฎร และคณะกรรมการการเลือกตั้ง ได้กำหนดให้วันที่ 8 เดือน กุมภาพันธ์ พ.ศ. 2569 เป็นวันเลือกตั้ง นั้น
# บัดนี้ คณะกรรมการประจำหน่วยเลือกตั้งได้ดำเนินการนับคะแนนสมาชิกสภาผู้แทนราษฎรแบบบัญชีรายชื่อของหน่วยเลือกตั้งที่ 1 หมู่ที่ 1 ตำบล/แขวง/เทศบาล แก่นมะกูด อำเภอ/เขต ป่าไม้
# เขตเลือกตั้งที่ 2 จังหวัด อุทัยธานี เสร็จสิ้นเป็นที่เรียบร้อยแล้ว ดังนั้น จึงขอรายงานผลการนับคะแนนของหน่วยเลือกตั้งดังกล่าว ดังนี้
# ๑. จำนวนผู้มีสิทธิเลือกตั้ง
# ๑.๑ จำนวนผู้มีสิทธิเลือกตั้งตามบัญชีรายชื่อผู้มีสิทธิเลือกตั้ง จำนวน 328 คน (สามร้อยยี่สิบแปด)
# ๑.๒ จำนวนผู้มีสิทธิเลือกตั้งที่มาแสดงตน (เฉพาะวันเลือกตั้ง) จำนวน 281 คน (สองร้อยแปดสิบเอ็ด)
# ๒. จำนวนบัตรเลือกตั้ง
# ๒.๑ จำนวนบัตรเลือกตั้งที่ได้รับจัดสรร จำนวน 340 บัตร (สามร้อยสี่สิบ)
# ๒.๒ จำนวนบัตรเลือกตั้งที่ใช้ จำนวน 281 บัตร (สองร้อยแปดสิบเอ็ด)
# ...

# %%
markdown = ocr_document(
    # pdf_or_image_path="../อำเภอบ้านไร่/ตำบลแก่นมะกรูด/หน่วยเลือกตั้งที่ 1/ส.ส.5ทับ18 (บช.).pdf",
    pdf_or_image_path="../อำเภอบ้านไร่/ตำบลแก่นมะกรูด/หน่วยเลือกตั้งที่ 1/ส.ส.5ทับ18.pdf",
    page_num=2                        # ประมวลผลหน้าที่ 2 ของ PDF (ค่าเริ่มต้นคือ 1, สำหรับรูปภาพจะเป็น 1 เสมอ)
)

# %%
display(Markdown(markdown))
# Out:
# ส.ส. ๕/๑๘(บช)
# สีขาว
#
# ชุดที่ ๑ เก็บไว้ในเดิมเพื่อส่งคณะกรรมการการเลือกตั้งประจำเขตเลือกตั้ง (แบบบัญชีรายชื่อ)
#
# ...

# %%
markdown = ocr_document(
    pdf_or_image_path="../อำเภอบ้านไร่/ตำบลแก่นมะกรูด/หน่วยเลือกตั้งที่ 1/ส.ส.5ทับ18 (บช.).pdf",
    page_num=3                        # ประมวลผลหน้าที่ 2 ของ PDF (ค่าเริ่มต้นคือ 1, สำหรับรูปภาพจะเป็น 1 เสมอ)
)

# %%
display(Markdown(markdown))
# Out:
# สีขาว
# ส.ส. ๕/๑๘(บช)
# จุดที่ ๑ เก็บไว้ในเล่มเพื่อส่งคณะกรรมการการเลือกตั้งประจำเขตเลือกตั้ง (แบบบัญชีรายชื่อ)
#
# ...
